# %%
import xarray as xr
import numpy as np
import pandas as pd
from datetime import timedelta
import functions.common as cf

# %%
datafiles = pd.read_csv('data_files_list_CP05MOAS-GL335-05-PARADM000.csv')
pd.set_option('display.max_colwidth', -1)
(datafiles)
# Out:
#        Unnamed: 0  \
# 0  deployment0001
# 1  deployment0002
# 2  deployment0003
# 3  deployment0004
# 4  deployment0005
# 5  deployment0001
# 6  deployment0002
# 7  deployment0003
# 8  deployment0004
# 9  deployment0005
#
#                                                                                                                                                                                                                                                                                                       datasets  \
# 0  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument/deployment0001_CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument_20141006T202152.905850-20141213T035750.235320.nc
# 1  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument/deployment0002_CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument_20151014T001900.237980-20151110T091836.233310.nc
# 2  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument/deployment0003_CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument_20160404T185705.311220-20160417T235956.145260.nc
# 3  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument/deployment0004_CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument_20160527T212312.351560-20160626T091401.747920.nc
# 4  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument/deployment0005_CP05MOAS-GL335-05-PARADM000-telemetered-parad_m_glider_instrument_20170116T150223.595370-20170304T045334.799840.nc
# 5  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0001_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20141006T202152.905850-20141213T073238.247380.nc
# 6  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0002_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20151014T001900.237980-20151110T091855.472810.nc
# 7  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0003_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20160404T185705.311220-20160417T235956.145260.nc
# 8  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0004_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20160529T204727.075500-20160626T091401.747920.nc
# 9  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0005_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20170116T150223.595370-20170304T093047.153350.nc
#
#            method
# 0  telemetered
# 1  telemetered
# 2  telemetered
# 3  telemetered
# 4  telemetered
# 5  recovered_host
# 6  recovered_host
# 7  recovered_host
# 8  recovered_host
# 9  recovered_host

# %%
reviewfiles = pd.read_csv('data_review_list_CP05MOAS-GL335-05-PARADM000.csv')
pd.set_option('display.max_colwidth', -1)
reviewfiles
# Out:
#        Unnamed: 0  \
# 0  deployment0001
# 1  deployment0002
# 2  deployment0003
# 3  deployment0004
# 4  deployment0005
#
#                                                                                                                                                                                                                                                                                                       datasets  \
# 0  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0001_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20141006T202152.905850-20141213T073238.247380.nc
# 1  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0002_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20151014T001900.237980-20151110T091855.472810.nc
# 2  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0003_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20160404T185705.311220-20160417T235956.145260.nc
# 3  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0004_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20160529T204727.075500-20160626T091401.747920.nc
# 4  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0005_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20170116T150223.595370-20170304T093047.153350.nc
#
#            method
# 0  recovered_host
# 1  recovered_host
# 2  recovered_host
# 3  recovered_host
# 4  recovered_host

# %%
deploy_list = pd.unique(datafiles['Unnamed: 0'])

# %%
d_info = pd.DataFrame()
d_dia = pd.DataFrame()
for item in deploy_list: 
    datalist = datafiles['datasets'][datafiles['Unnamed: 0'] == item]
    method = datafiles['method'][datafiles['Unnamed: 0'] == item]
    
    if len(datalist) == 1:
        note = 'No comparison: Data exist from only 1 delivery method.'
    elif len(datalist) > 1 & len(datalist) <= 3:
        note = 'Do comparison: Data exist from 2 different delivery methods.'
    else:
        note = 'No comparison: Data exist for more than 3 delivery methods. Please provide fewer datasets for analysis.'
    
    umethods = [u.split('/')[-1].split('-')[4] for u in datalist]
    ustreams = [u.split('/')[-2].split('-')[-1] for u in datalist]
    
#     # check stream names
#     omit_word = ['_dcl', '_imodem', '_conc']   
#     ss_new = []
    
#     for s in ustreams:
#         wordi = []
#         for word in omit_word:
#             if word in s:
#                 wordi.append(word)
#                 break

#         if wordi:
#             fix = s.split(wordi[0])
#             if len(fix) == 2:
#                 ss_new.append(fix[0] + fix[1].split('_recovered')[0])
#         elif '_recovered' in s:
#             ss_new.append(s.split('_recovered')[0])

#         else:
#             ss_new.append(s)
           
    d0 = pd.DataFrame({'note': [note],
                       'methods': [umethods],
                       'streams':[ustreams], 
                       'datasets': [datalist.values]
                      }, index=[item])
    d_info = d_info.append(d0)
    
#     d_dia = d_dia.append(d0['note']) #, index=[d0.index.values]
pd.set_option('display.max_colwidth', -1)
d_info[['note', 'methods', 'streams']]
# Out:
#                                                                         note  \
# deployment0001  Do comparison: Data exist from 2 different delivery methods.
# deployment0002  Do comparison: Data exist from 2 different delivery methods.
# deployment0003  Do comparison: Data exist from 2 different delivery methods.
# deployment0004  Do comparison: Data exist from 2 different delivery methods.
# deployment0005  Do comparison: Data exist from 2 different delivery methods.
#
#                                       methods  \
# deployment0001  [telemetered, recovered_host]
# deployment0002  [telemetered, recovered_host]
# deployment0003  [telemetered, recovered_host]
# deployment0004  [telemetered, recovered_host]
# deployment0005  [telemetered, recovered_host]
#
#                                                               streams
# deployment0001  [parad_m_glider_instrument, parad_m_glider_recovered]
# deployment0002  [parad_m_glider_instrument, parad_m_glider_recovered]
# deployment0003  [parad_m_glider_instrument, parad_m_glider_recovered]
# deployment0004  [parad_m_glider_instrument, parad_m_glider_recovered]
# deployment0005  [parad_m_glider_instrument, parad_m_glider_recovered]

# %%
df = pd.DataFrame()
df_sum =  pd.DataFrame()
for ii in range(len(d_info)): 
    index_i = d_info.index.values[ii]
    print(ii, '\n',index_i)
   
    if len(d_info['methods'].values[ii]) == 2:
        ds0 = xr.open_dataset(d_info['datasets'].values[ii][0])
        ds0 = ds0.swap_dims({'obs': 'time'})        
        ds0_sci_vars = cf.return_science_vars(d_info['streams'].values[ii][0])
        ds0_method = d_info['methods'].values[ii][0]
        
        ds1 = xr.open_dataset(d_info['datasets'].values[ii][1])
        ds1 = ds1.swap_dims({'obs': 'time'})        
        ds1_sci_vars = cf.return_science_vars(d_info['streams'].values[ii][1])
        ds1_method = d_info['methods'].values[ii][1]
        
        # define preferred method
        if reviewfiles['method'].values[ii] == ds0_method:
            preferred_method = 'ds0'
        elif reviewfiles['method'].values[ii] == ds1_method: 
            preferred_method = 'ds1'
              
        # find where the variable long names are the same
        ds0names = cf.long_names(ds0, ds0_sci_vars)
        ds0names.rename(columns={'name': 'name_ds0'}, inplace=True)
        
        ds1names = cf.long_names(ds1, ds1_sci_vars)
        ds1names.rename(columns={'name': 'name_ds1'}, inplace=True)
        
        mapping = pd.merge(ds0names, ds1names, on='long_name', how='inner')
        print(mapping)
        df, missing_data_list, diff_gzero_list, var_list = cf.compare_datasets(df, mapping, preferred_method, index_i,ds0, ds0_method, ds1, ds1_method)
    else:
        print(d_info['note'].values[ii])
    
    fd_test = cf.found_data_in_another_stream(missing_data_list)
    print('i am here')
    comparison_details = cf.found_data_in_another_stream_diff(fd_test, diff_gzero_list, var_list)
    
    df_sum0 = pd.DataFrame({'data_comparison': [fd_test],
                            'comparison_details': [comparison_details]}
                           , index= [d_info.index.values[ii]])
    df_sum = df_sum.append(df_sum0)
# Out:
# 0
#  deployment0001
#          name_ds0                            long_name        name_ds1
# 0  sci_bsipar_par  Photosynthetically Active Radiation  sci_bsipar_par
# 1  sci_bsipar_par  Photosynthetically Active Radiation  parad_m_par
# 2  parad_m_par     Photosynthetically Active Radiation  sci_bsipar_par
# 3  parad_m_par     Photosynthetically Active Radiation  parad_m_par
# i am here
# 1
#  deployment0002
#          name_ds0                            long_name        name_ds1
# 0  sci_bsipar_par  Photosynthetically Active Radiation  sci_bsipar_par
# 1  sci_bsipar_par  Photosynthetically Active Radiation  parad_m_par
# 2  parad_m_par     Photosynthetically Active Radiation  sci_bsipar_par
# 3  parad_m_par     Photosynthetically Active Radiation  parad_m_par
# i am here
# 2
#  deployment0003
#          name_ds0                            long_name        name_ds1
# 0  sci_bsipar_par  Photosynthetically Active Radiation  sci_bsipar_par
# 1  sci_bsipar_par  Photosynthetically Active Radiation  parad_m_par
# 2  parad_m_par     Photosynthetically Active Radiation  sci_bsipar_par
# 3  parad_m_par     Photosynthetically Active Radiation  parad_m_par
# i am here
# 3
#  deployment0004
#          name_ds0                            long_name        name_ds1
# 0  sci_bsipar_par  Photosynthetically Active Radiation  sci_bsipar_par
# 1  sci_bsipar_par  Photosynthetically Active Radiation  parad_m_par
# 2  parad_m_par     Photosynthetically Active Radiation  sci_bsipar_par
# 3  parad_m_par     Photosynthetically Active Radiation  parad_m_par
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-98d09db79676> in <module>
#      35         print(d_info['note'].values[ii])
#      36
# ---> 37     fd_test = cf.found_data_in_another_stream(missing_data_list)
#      38     print('i am here')
#      39     comparison_details = cf.found_data_in_another_stream_diff(fd_test, diff_gzero_list, var_list)
#
# ~/Documents/NSFEduSupport/github/8thEGOMeeting-notebooks/functions/common.py in found_data_in_another_stream(missing_data_list)
#     416                 continue
#     417             else:
# --> 418                 md = ast.literal_eval(md)
#     419                 n_missing_gaps.append(len(md['missing_data_gaps']))
#     420                 n_missing_days.append(md['n_missing_days_total'])
#
# NameError: name 'ast' is not defined

# %%
df = df[df['unit_test'] != 'fail']
df = df[df['unit'] != 'bar']

# %%
pd.set_option('display.max_colwidth', -1)
(df)

# %%
pd.set_option('display.max_colwidth', -1)
(df_sum)
