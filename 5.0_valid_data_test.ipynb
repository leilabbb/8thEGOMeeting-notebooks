# %%
import xarray as xr
import numpy as np
import pandas as pd
import functions.common as cf
from IPython.display import Image
from IPython.core.display import HTML

# %%
reviewlist = pd.read_csv('define_datareview_list_GL335.csv')
pd.set_option('display.max_colwidth', -1)
(reviewlist)
# Out:
#        Unnamed: 0  \
# 0  deployment0001
# 1  deployment0002
# 2  deployment0003
# 3  deployment0004
# 4  deployment0005
#
#                                                                                                                                                                                                                                                                                                       datasets  \
# 0  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0001_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20141006T202152.905850-20141213T073238.247380.nc
# 1  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0002_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20151014T001900.237980-20151110T091855.472810.nc
# 2  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0003_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20160404T185705.311220-20160417T235956.145260.nc
# 3  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0004_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20160529T204727.075500-20160626T091401.747920.nc
# 4  https://opendap.oceanobservatories.org/thredds/dodsC/ooi/lgarzio@marine.rutgers.edu/20190509T131304-CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered/deployment0005_CP05MOAS-GL335-05-PARADM000-recovered_host-parad_m_glider_recovered_20170116T150223.595370-20170304T093047.153350.nc
#
#            method
# 0  recovered_host
# 1  recovered_host
# 2  recovered_host
# 3  recovered_host
# 4  recovered_host

# %%
df = pd.DataFrame()
dr = pd.DataFrame()
valid_list = list(np.zeros(len(reviewlist)))
for index, row in reviewlist.iterrows():
    rd = row['datasets'].split('/')[-1].split('_')[1][0:27]
    stream = row['datasets'].split('/')[-1].split('-')[5].split('_2')[0]
    sci_vars = cf.return_science_vars(stream)
    ds = xr.open_dataset(row['datasets'], mask_and_scale=False)
    ds = ds.swap_dims({'obs': 'time'})

    # calculate statistics for science variables, excluding outliers +/- 5 SD    
    index_i = row['Unnamed: 0']
    valid_list_index = []
    for sv in sci_vars:
        valid_sci_dic = cf.validate_sci_var_report(rd, sv, ds, index_i, valid_list_index)       
        df = df.append(valid_sci_dic)     
    valid_list[index] = df['pvd_test'].values[-1]
    dr0 = pd.DataFrame({'valid_list': [valid_list[index]]}, index=[index_i])
    dr = dr.append(dr0)
dr
# Out:
#                                 valid_list
# deployment0001  {'99': 1, '25': 1, '0': 1}
# deployment0002  {'99': 1, '25': 1, '0': 1}
# deployment0003  {'99': 3}
# deployment0004  {'99': 2, '0': 1}
# deployment0005  {'99': 1, '0': 2}

# %%
pd.set_option('display.max_colwidth', -1)
(df)
# Out:
#                              sv             var_units  fv:fill_value  n_fv  \
# deployment0001  sci_bsipar_par   µmol photons m-2 s-1 NaN             0
# deployment0001  sci_bsipar_temp  ºC                   NaN             0
# deployment0001  parad_m_par      µmol photons m-2 s-1 NaN             0
# deployment0002  sci_bsipar_par   µmol photons m-2 s-1 NaN             0
# deployment0002  sci_bsipar_temp  ºC                   NaN             0
# deployment0002  parad_m_par      µmol photons m-2 s-1 NaN             0
# deployment0003  sci_bsipar_par   µmol photons m-2 s-1 NaN             0
# deployment0003  sci_bsipar_temp  ºC                   NaN             0
# deployment0003  parad_m_par      µmol photons m-2 s-1 NaN             0
# deployment0004  sci_bsipar_par   µmol photons m-2 s-1 NaN             0
# deployment0004  sci_bsipar_temp  ºC                   NaN             0
# deployment0004  parad_m_par      µmol photons m-2 s-1 NaN             0
# deployment0005  sci_bsipar_par   µmol photons m-2 s-1 NaN             0
# deployment0005  sci_bsipar_temp  ºC                   NaN             0
# deployment0005  parad_m_par      µmol photons m-2 s-1 NaN             0
#
#                gr: global_range     n_gr    n_nan num_outliers  n_stats  \
# deployment0001  [0.0, 2500.0]    3699171  0        3699171      31755
# deployment0001  [-2.0, 40.0]     0        0        1022         3729904
# deployment0001  [0.0, 2500.0]    2288817  0        2298262      1432664
# deployment0002  [0.0, 2500.0]    1088649  0        1088649      27644
# deployment0002  [-2.0, 40.0]     0        0        1112         1115181
# deployment0002  [0.0, 2500.0]    644249   0        647811       468482
# deployment0003  [0.0, 2500.0]    77       0        3534         479508
# deployment0003  [-2.0, 40.0]     0        0        486          482556
# deployment0003  [0.0, 2500.0]    0        0        2732         480310
# deployment0004  [0.0, 2500.0]    1535163  0        1535163      1125
# deployment0004  [-2.0, 40.0]     0        0        1125         1535163
# deployment0004  [0.0, 2500.0]    558      0        13298        1522990
# deployment0005  [0.0, 2500.0]    3351808  0        3351808      742
# deployment0005  [-2.0, 40.0]     0        0        0            3352550
# deployment0005  [0.0, 2500.0]    0        3352550  None         0
#
#                    mean   vmin     vmax       sd  percent_valid_data  \
# deployment0001  792.534  0      1784.76  886.777  0.85
# deployment0001  16.6991  11.5   23.94    2.2236   99.97
# deployment0001  13.2937  0      363.427  36.8723  38.40
# deployment0002  691.979  0      1784.76  869.587  2.48
# deployment0002  17.506   12.74  23.53    1.6865   99.90
# deployment0002  18.5074  0      574.032  56.1156  41.97
# deployment0003  9.2554   0      370.293  34.8497  99.27
# deployment0003  12.455   7.76   15.65    2.159    99.90
# deployment0003  0        0      0.0004   0        99.43
# deployment0004  0        0      0        0        0.07
# deployment0004  14.5159  10.67  19.79    1.0753   99.93
# deployment0004  13.5089  0      617.407  57.9907  99.13
# deployment0005  0        0      0        0        0.02
# deployment0005  11.8738  0      16.48    2.5958   100.00
# deployment0005  None     None   None     None     0.00
#
#                                   pvd_test    dlst
# deployment0001  {'0': 1}                    [0]
# deployment0001  {'99': 1, '0': 1}           [0]
# deployment0001  {'99': 1, '25': 1, '0': 1}  [0, 2]
# deployment0002  {'0': 1}                    [0]
# deployment0002  {'99': 1, '0': 1}           [0]
# deployment0002  {'99': 1, '25': 1, '0': 1}  [0, 2]
# deployment0003  {'99': 1}                   []
# deployment0003  {'99': 2}                   []
# deployment0003  {'99': 3}                   []
# deployment0004  {'0': 1}                    [0]
# deployment0004  {'99': 1, '0': 1}           [0]
# deployment0004  {'99': 2, '0': 1}           [0]
# deployment0005  {'0': 1}                    [0]
# deployment0005  {'99': 1, '0': 1}           [0]
# deployment0005  {'99': 1, '0': 2}           [0, 2]

# %% [markdown]
# plot all data to show data
#
# remove zeros and errors
